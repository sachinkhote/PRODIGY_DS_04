# %% [markdown]
# # TASK 4

# %% [markdown]
# #### Personal Information
#
# **Name:** Sachin Khote
# **Domain:** Data Science
# **Batch:** NOVEMBER

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("twitter_training.csv")
validation_data = pd.read_csv("twitter_validation.csv")

# %%
train_head = train_data.head()
validation_head = validation_data.head()
train_head, validation_head
# Out:
# (   2401  Borderlands  Positive  \
#  0  2401  Borderlands  Positive
#  1  2401  Borderlands  Positive
#  2  2401  Borderlands  Positive
#  3  2401  Borderlands  Positive
#  4  2401  Borderlands  Positive
#
#    im getting on borderlands and i will murder you all ,
#  0  I am coming to the borders and I will kill you...
#  1  im getting on borderlands and i will kill you ...
#  2  im coming on borderlands and i will murder you...
#  3  im getting on borderlands 2 and i will murder ...
#  4  im getting into borderlands and i can murder y...     ,
#     3364   Facebook Irrelevant  \
#  0   352     Amazon    Neutral
#  1  8312  Microsoft   Negative
#  2  4371      CS-GO   Negative
#  3  4433     Google    Neutral
#  4  6273       FIFA   Negative
#
#    I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣
#  0  BBC News - Amazon boss Jeff Bezos rejects clai...
#  1  @Microsoft Why do I pay for WORD when it funct...
#  2  CSGO matchmaking is so full of closet hacking,...
#  3  Now the President is slapping Americans in the...
#  4  Hi @EAHelp I’ve had Madeleine McCann in my cel...                                                                                                                                                                                                  )

# %%
missing_train = train_data.isnull().sum()
missing_validation = validation_data.isnull().sum()
     

duplicates_train = train_data.duplicated().sum()
duplicates_validation = validation_data.duplicated().sum()

missing_train, missing_validation, duplicates_train, duplicates_validation
# Out:
# (2401                                                       0
#  Borderlands                                                0
#  Positive                                                   0
#  im getting on borderlands and i will murder you all ,    686
#  dtype: int64,
#  3364                                                                                                                                                                                                                                                  0
#  Facebook                                                                                                                                                                                                                                              0
#  Irrelevant                                                                                                                                                                                                                                            0
#  I mentioned on Facebook that I was struggling for motivation to go for a run the other day, which has been translated by Tom’s great auntie as ‘Hayley can’t get out of bed’ and told to his grandma, who now thinks I’m a lazy, terrible person 🤣    0
#  dtype: int64,
#  2700,
#  0)

# %%
train_sentiment_distribution = train_data.iloc[:, 2].value_counts()
validation_sentiment_distribution = validation_data.iloc[:, 2].value_counts()
     

unique_entities_train = train_data.iloc[:, 1].nunique()

train_sentiment_distribution, validation_sentiment_distribution, unique_entities_train
# Out:
# (Positive
#  Negative      22542
#  Positive      20831
#  Neutral       18318
#  Irrelevant    12990
#  Name: count, dtype: int64,
#  Irrelevant
#  Neutral       285
#  Positive      277
#  Negative      266
#  Irrelevant    171
#  Name: count, dtype: int64,
#  32)

# %%
train_data_cleaned = train_data.drop_duplicates()

train_data_cleaned = train_data_cleaned.dropna(subset=[train_data.columns[3]])
     

remaining_duplicates_train = train_data_cleaned.duplicated().sum()
remaining_missing_train = train_data_cleaned.isnull().sum()

remaining_duplicates_train, remaining_missing_train
# Out:
# (0,
#  2401                                                     0
#  Borderlands                                              0
#  Positive                                                 0
#  im getting on borderlands and i will murder you all ,    0
#  dtype: int64)

# %%
# Sentiment Distribution Plots
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.countplot(data=train_data_cleaned, x=train_data_cleaned.columns[2], order=['Positive', 'Negative', 'Neutral', 'Irrelevant'], ax=ax[0], palette='pastel')  # Use a different color palette
ax[0].set_title('Sentiment Distribution in Training Data')
ax[0].set_ylabel('Count')
ax[0].set_xlabel('Sentiment')

sns.countplot(data=validation_data, x=validation_data.columns[2], order=['Positive', 'Negative', 'Neutral', 'Irrelevant'], ax=ax[1], palette='Set3')  # Use a different color palette
ax[1].set_title('Sentiment Distribution in Validation Data')
ax[1].set_ylabel('Count')
ax[1].set_xlabel('Sentiment')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Entity Distribution Plot
plt.figure(figsize=(15, 7))

sns.countplot(data=train_data_cleaned, y=train_data_cleaned.columns[1], order=train_data_cleaned[train_data_cleaned.columns[1]].value_counts().index, palette='muted')  # Use a different color palette
plt.title('Entity Distribution in Training Data')
plt.xlabel('Count')
plt.ylabel('Entity')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
train_data_cleaned['message_length'] = train_data_cleaned[train_data_cleaned.columns[3]].apply(len)
validation_data['message_length'] = validation_data[validation_data.columns[3]].apply(len)
     
# Message Length Distribution Plots
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.histplot(train_data_cleaned['message_length'], bins=50, ax=ax[0], color='coral')  # Use a different color
ax[0].set_title('Message Length Distribution in Training Data')
ax[0].set_ylabel('Frequency')
ax[0].set_xlabel('Message Length')

sns.histplot(validation_data['message_length'], bins=50, ax=ax[1], color='lightgreen')  # Use a different color
ax[1].set_title('Message Length Distribution in Validation Data')
ax[1].set_ylabel('Frequency')
ax[1].set_xlabel('Message Length')

plt.tight_layout()
plt.show()
# Out:
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Sentiment Distribution by Entity Plot
plt.figure(figsize=(18, 10))

sns.countplot(data=train_data_cleaned, y=train_data_cleaned.columns[1], hue=train_data_cleaned.columns[2], order=train_data_cleaned[train_data_cleaned.columns[1]].value_counts().index, palette='Blues')  # Use a different color palette
plt.title('Sentiment Distribution by Entity in Training Data')
plt.xlabel('Count')
plt.ylabel('Entity')
plt.legend(title='Sentiment')
plt.tight_layout()
plt.show()
# Out:
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Message Length Distribution by Sentiment Plot
fig, ax = plt.subplots(1, 2, figsize=(15, 5))

sns.boxplot(data=train_data_cleaned, x=train_data_cleaned.columns[2], y='message_length', ax=ax[0], palette='pastel', order=['Positive', 'Negative', 'Neutral', 'Irrelevant'])  # Use a different color palette
ax[0].set_title('Message Length Distribution by Sentiment in Training Data')
ax[0].set_ylabel('Message Length')
ax[0].set_xlabel('Sentiment')
ax[0].set_ylim(0, 300)

sns.boxplot(data=validation_data, x=validation_data.columns[2], y='message_length', ax=ax[1], palette='Set3', order=['Positive', 'Negative', 'Neutral', 'Irrelevant'])  # Use a different color palette
ax[1].set_title('Message Length Distribution by Sentiment in Validation Data')
ax[1].set_ylabel('Message Length')
ax[1].set_xlabel('Sentiment')
ax[1].set_ylim(0, 300)

plt.tight_layout()
plt.show()
# Out:
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\praful\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
